# %% [markdown]
# # Basic Assignment 4

# %% [markdown]
# ### Q1 What exactly is  [ ]?
#
# #### Answer:-
# #### It a square bracket which defines empty list value. eg: l = [1,2,3,4] this is a list.

# %% [markdown]
# ### Q2. In a list of values stored in a variable called spam, how would you assign the value &#39;hello&#39; as the third value? (Assume [2, 4, 6, 8, 10] are in spam.)

# %%
#Answer
spam = [2,4,6,8,10]

spam[2]="hellow"

spam
# Out:
# [2, 4, 'hellow', 8, 10]

# %% [markdown]
# ### Let's pretend the spam includes the list[ 'a', 'b', 'c', 'd' ] for the next three queries.

# %% [markdown]
# ### Q3.What is the value of spam[int(int(&#39;3&#39; * 2) / 11)]?

# %%
spam = ['a','b','c','d']

spam[int(int('3'*2)/11)]
# Out:
# 'd'

# %% [markdown]
# ### Q4 What is the value of spam[-1]?

# %%
#Answer
spam = ['a','b','c','d']

spam[-1]
# Out:
# 'd'

# %% [markdown]
# ### Q5 What is the value of spam[:2]?

# %%
#Answer
spam = ['a','b','c','d']
spam[:2]
# Out:
# ['a', 'b']

# %% [markdown]
# ### let's pretend bacon has the list [3.14, 'cat', 11, 'cat', True] for the next three questions.

# %% [markdown]
# ### Q6 What is the value of bacon.index('cat')?

# %%
bacon = [3.14,'cat',11,'cat',True]

bacon.index('cat')
# Out:
# 1

# %% [markdown]
# ### Q7 How does bacon.append(99) change the look of the list value in bacon?

# %%
bacon = [3.14,'cat',11,'cat',True]

bacon.append(99)

bacon
# Out:
# [3.14, 'cat', 11, 'cat', True, 99]

# %% [markdown]
# ### Q8 How does bacon.remove('cat') change the look of the list in bacon?

# %%
bacon.remove('cat')
bacon
# Out:
# [3.14, 11, 'cat', True, 99]

# %% [markdown]
# ### Q9 What are the list concatenation and list replication operators?
#
# #### Answer:
# #### operator for list concatenation is +, and for list replication *

# %% [markdown]
# ### Q10 What is difference between the list methods append() and insert()?
#
# #### Answer:
# #### insert() function allows us to add a specific element at a specified index of the list
# #### append() function add the element only at end of the list.

# %% [markdown]
# ### Q11 What are the two methods for removing items from a list?
#
# #### Answer:
# #### 1) remove() = It helps to remove the very first given element matching from the list.
# #### 2) pop() = It removes an element from the list based on the index given.
# #### 3) clear() = It  remove all the elements present in the list.

# %% [markdown]
# ## Q12 Describe how list values and string values are identical.
#
# #### Answer
#
# #### The similarity between Lists and Strings in Python is that both are sequences. Both work on indexing operations, hence their are many inbuilt function which are similar for list concatination and string concatination.

# %% [markdown]
# ## Q13 What's the difference between tuples and lists?
#
# #### Answer:
#
# #### 1)Lists are mutable -- 1)Tuples are immutable
# #### 2)Implication of iterations is Time-consuming --	2)The implication of iterations is comparatively Faster
# #### 3)The list is better for performing operations, such as insertion and deletion -- 3)Tuple data type is appropriate for accessing the elements
# #### 4)Lists consume more memory -- 4)Tuple consume less memory as compared to the list
# #### 5)Lists have several built-in methods -- 5)Tuple does not have many built-in methods.
# #### 6)The unexpected changes and errors are more likely to occur -- 6)In tuple, it is hard to take place.

# %% [markdown]
# ## Q14 How do you type a tuple value that only contains the integer 42?

# %%
#Answer
t = (42,)
type(t)
# Out:
# tuple

# %% [markdown]
# ## Q15 How do you get a list value's tuple form? How do you get a tuple value's list form?
#
# #### Answer:
#
# #### We can create tupels by putting required data in Parenthese and then we put that tuples into defined list.
# eg:- l1 = [ (1, 2, 3), ('cat', 'dog', 'cow'), (45.56, 789.12) ]

# %% [markdown]
# ## Q16. Variables that &quot;contain&quot; list values are not necessarily lists themselves. Instead, what do they contain?
#
# #### Answer
#
# #### Variables will contain references to list values rather than list values themselves. But for strings and integer values, variables simply contain the string or integer value

# %% [markdown]
# ## Q17. How do you distinguish between copy.copy() and copy.deepcopy()?
#
# #### Answer:
# #### copy() create reference to original object copy. If you change copied object, you change the original object. deepcopy() creates new object of copy, and does real copying of original object to new one.
