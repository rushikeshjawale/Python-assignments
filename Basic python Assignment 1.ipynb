# %% [markdown]
# 1.In the below elements which of them are values or an expression?
#    eg:- values can be integer or string and expressions will be mathematical operators
#         * , 'hello', -87.8, -, /, 6
#
# Answer:-
#
# values: 'hello', -87.8, 6
# expression: *, -, /

# %% [markdown]
# 2.What is the difference between string and variable?
#
# Answer:-
#
# variable is a entity where we store our function.
# string is a function which is represented in single quotes or double quotes.

# %% [markdown]
# 3.Describe three different data types.
#
# Answer:-
#
# Three different types of data types are as follows:
# a) Integer: it is a numerical type of data type which have nodecimal point.
# b) boolean: it is a True and False data type wghich hold values of 1 and 0 respectively.
# c) complex: it is a data type which hold complex number eg: 2+5j
#             here 2 is real and 5 is imaginary.

# %% [markdown]
# 4.What is an expression made up of? What do all expressions do?
#
# Answer:-
#
# Expression are mathematical operators which are made up of +,-,/,*,<,>.
# All expression are use to conduct mathematical operations like add, multiply, divide,substract and so on.

# %% [markdown]
# 5.This assignment statements, like spam = 10.What is the difference between an expression and a statement?
#
# Answer:-
#
# In above statement spam = 10, it means that spam holds value of 10 or spam has a value of 10.
# here, (spam)is variable, (=) is expression, (10) is integer.
# so basically statement is a logical line which gives meaning to a code made of using one or more functions and variables
# and expressions. Where expression is a mathematical operator which add meaning or which completes the statement.

# %% [markdown]
# 6.After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
#
# Answer:-
#
# accoring to above code:
# Step 1: bacon=22 it means current value of bacon is 22.
# Step 2: in 2nd step we add value 1 in previous value of bacon. so now current value of bacon is 23.
# so in above code variable bacone contains value 23.

# %% [markdown]
# 7.What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3

# %%
#Answer

'spam' + 'spamspam','spam' * 3
# Out:
# ('spamspamspam', 'spamspamspam')

# %% [markdown]
# 8.Why is eggs a valid variable name while 100 is invalid?
#
# Answer:-
#
# Here 100 represent as a integer data type like other numbers without decimal like 22,450, 5000 etc.
# An integer cannot hold other value because it has its own value. Where eggs is a word which dont fall in any data type cartegory so it is suitable as a valid variable, since we can assign any data type value in it.

# %% [markdown]
# 9.What three functions can be used to get the integer, floating-point number, or string version of a value?
#
# Answer:-
#
# int() is used for integer. float() is used for floatingpoint. str() is used for string

# %% [markdown]
# 10.Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'

# %% [markdown]
# Answer:-

# %%
'I have eaten ' + 99 + ' burritos.'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11504/1774935878.py in <module>
# ----> 1 'I have eaten ' + 99 + ' burritos.'
#
# TypeError: can only concatenate str (not "int") to str

# %%
# As per above error a string and integer cannot concatenate, so to solve this we have to conver 99 into string data type.

'I have eaten ' + str(99 + ' burritos.'
# Out:
# 'I have eaten 99 burritos.'
