# %% [markdown]
# # Basic Assignment 6

# %% [markdown]
# ## Q1 What are escape characters, and how do you use them?
#
# ### Answer:
# In Python strings, the backslash \ is a special character, also called the "escape" character. It is used in representing certain whitespace characters.

# %% [markdown]
# ## Q2 What do the escape characters n and t stand for?

# %% [markdown]
# ### Answer:
# Escape character \n stands for New Line.
#
# Escape character \t stands for Tab.

# %% [markdown]
# ## Q3 What is the way to include backslash characters in a string?

# %%
# Answer:
# Below example is the way to include backlash in the string.


s = "This is the way of \"Samurai\", we fight and never loose hope."
print(s)

"""Note:In this example if we use double quote in double quote without backslash then it will give syntex error."""
# Out:
# This is the way of "Samurai", we fight and never loose hope.
# 'Note:In this example if we use double quote in double quote without backslash then it will give syntex error.'

# %% [markdown]
# ## Q4 The string "Howl's Moving castle" is a corect value. Why isn't the single quote character in the word Howl's not escaped a problem?

# %% [markdown]
# ### Answer:
# The single quote in Howl's is fine because you've used double quotes to mark the beginning and end of the string.

# %% [markdown]
# ## Q5 How do you write a string of newlines if you don&#39;t want to use the n character?
#
# ### Answer:
# Multiline strings allow you to use newlines in strings without the \n escape character.

# %%
print("""This is my first project in pycharm.
please check weather their is correction or not.
if their is a correction kindly email me the required changes.""")
# Out:
# This is my first project in pycharm.
# please check weather their is correction or not.
# if their is a correction kindly email me the required changes.

# %% [markdown]
# ## Q6 What are the values of the given expressions?
# a. 'Hello, world!' [1]
#
# b. 'Hello, world!' [0:5]
#
# c. 'Hello, world!' [:5]
#
# d. 'Hello, world!' [3:]
#
# #### Answer:
# This is a string indexing operation of above string respectively.

# %%
a,b,c,d = 'Hello world!'[1], 'Hellow world!'[0:5], 'Hellow world!'[:5], 'Hellow world!'[3:]
print(a,b,c,d)
# Out:
# e Hello Hello low world!

# %% [markdown]
# ## Q7 What are the values of the following expressions?
# a = 'Hello'.upper()
#
# b = 'Hello'.upper().isupper()
#
# c = 'Hello'.upper().lower()
#
# ### Answer:

# %%
a = 'Hello'.upper()
b = 'Hello'.upper().isupper()
c = 'Hello'.upper().lower()

# %%
print(a,b,c)
# Out:
# HELLO True hello

# %% [markdown]
# ## Q8 What are the values of the following expressions?

# %% [markdown]
# 'Remember, remember, the fifth of July.'.split()
#
# '-'.join('There can only one.'.split())

# %% [markdown]
# ### Answer:

# %%
print('Remember, remember, the fifth of July.'.split())
print('-'.join('There can only one.'.split()))
# Out:
# ['Remember,', 'remember,', 'the', 'fifth', 'of', 'July.']
# There-can-only-one.

# %% [markdown]
# ## Q9 What are the methods for right-justifying, left-justifying, and centering a string?
#
# ### Answer:
#
# The rjust(), ljust(), and center() string methods

# %% [markdown]
# ## Q10 What is the best way to remove whitespace characters from the start or end?

# %% [markdown]
# ### Answer:
# lstrip() this function is used to remove white space from start.
#
# rstrio() this function is used to remove white space from end.
#
# strip()  this function is used to remove white space from both end.

# %%
r = " rishi "
r.strip(),r.lstrip(),r.rstrip()
# Out:
# ('rishi', 'rishi ', ' rishi')
